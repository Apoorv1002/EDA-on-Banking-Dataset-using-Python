# %% [markdown]
# # Dataset Source:
#
# The data that we are going to use for this project is a subset of an open source Bank Marketing Data Set from the UCI ML repository: https://archive.ics.uci.edu/ml/citation_policy.html.
#
# This dataset is publicly available for research. The details are described in [Moro et al., 2014]. Please include this citation if you plan to use this database: [Moro et al., 2014] S. Moro, P. Cortez and P. Rita. A Data-Driven Approach to Predict the Success of Bank Telemarketing. Decision Support Systems, Elsevier, 62:22-31, June 2014.

# %% [raw]
# The first step is to push the '.csv' format dataset into a pandas data frame. A pandas data frame is a 2D data structure, similar to an array or a table made of rows and columns. It makes analysis and exploration of data very convenient.
#
# For this, we will first import the pandas library and then have a variable 'df' refer to the data frame storing the dataset. We will also give semicolon as the separator to the read_csv method of pandas.

# %%
import pandas as pd
df=pd.read_csv('E:/Banking EDA/bank-additional-full.csv', sep=';')

# %% [raw]
# The dataset has been stored in the data frame referenced by variable 'df'.
# The print() method when applied to the data frame will print the first five and last five rows of the dataset while the head() method will print the same number of rows as supplied as argument to it. By default, the head() method returns the first five rows of the dataset when no argument is given to it.

# %%
print(df)
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
df.head(3)
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          93.994          -36.4      4.857       5191.0  no
# 1          93.994          -36.4      4.857       5191.0  no
# 2          93.994          -36.4      4.857       5191.0  no
#
# [3 rows x 21 columns]

# %% [raw]
# Now that the dataset has been successfully read into the data frame 'df', let us look at some very handy methods of pandas that give us basic information about our dataframe.

# %% [raw]
# The size attribute returns the total number of cells in the data frame.
# Number of cells= Number of rows*Number of columns

# %%
df.size
# Out:
# 864948

# %% [raw]
# The shape attribute returns the number of rows and the number of columns together embedded in a tuple.

# %%
df.shape
# Out:
# (41188, 21)

# %% [raw]
# The ndim attribute returns the dimensions of a data frame/series.
#
# Since data frames are 2D structures, the dimensionality of data frames is two.
# Since pandas series are 1D structures, the dimensionality of pandas series is one.

# %%
df.ndim
# Out:
# 2

# %%
df['age'].ndim
# Out:
# 1

# %% [raw]
# The 'columns' attribute returns a list of column names of the data frame.

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %% [raw]
# For a more detailed description of columns in the data frame, we can also use the info() method, which returns information like index range, total number of rows (column wise) and if they have null values or not, their data types etc.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %% [raw]
# As visible, no empty cells are present in the dataset. Had there been any empty cells in the dataset, we could have used the fillna() or fill() method to fill them with a suitable value (mean/median/mode or any other value of choice).

# %% [raw]
# To only see the data types of all columns in the data frame, we can use the dtypes attribute to return all column names as a pandas series object, which can be accessed by any variable name, like 'cname' in this case.

# %%
cname=df.dtypes
print(cname)
# Out:
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %% [raw]
# Another extremely important data exploration method provided by pandas is the describe() method.
#
# The describe() method returns some basic statistical information about our data frame, like the mean, root mean square standard deviation, minimum and maximum, percentiles [25,50,70 by default] for numerical columns.
# For non-numeric string like columns, it returns data like unique, top, count, frequency etc.
#
# By default, the describe() method ignores non-numeric columns of a data frame.
# Note: 'NaN' denotes missing values.

# %%
df.describe(include='all')
# Out:
#                 age     job  marital          education default housing  \
# count   41188.00000   41188    41188              41188   41188   41188
# unique          NaN      12        4                  8       3       3
# top             NaN  admin.  married  university.degree      no     yes
# freq            NaN   10422    24928              12168   32588   21576
# mean       40.02406     NaN      NaN                NaN     NaN     NaN
# std        10.42125     NaN      NaN                NaN     NaN     NaN
# min        17.00000     NaN      NaN                NaN     NaN     NaN
# 25%        32.00000     NaN      NaN                NaN     NaN     NaN
# 50%        38.00000     NaN      NaN                NaN     NaN     NaN
# 75%        47.00000     NaN      NaN                NaN     NaN     NaN
# max        98.00000     NaN      NaN                NaN     NaN     NaN
#
#          loan   contact  month day_of_week  ...      campaign         pdays  \
# ...

# %% [raw]
# The above data frame information generates some very valuable business insights:
#
# 1. Look at the row with label 'top': Clearly indicated that most customers belong to category [job:admin], are married, have a university degree and have taken a housing loan. Targetting people with such characteristicks holds a much greater chance of business success than others.
# 2. Look at the row with label 'frequency': Clearly indicated that [job:admin] people make up about 25% of our total customers [10422/41188], almost 60.5% of our customers are married[24928/41188] and about 29.5% of our customers are university degree holders [12168/41188].
# 3. Look at the row with label 'mean': Clearly indicated that our average customer is 40 years of age.
#
# Many such inferences can be further drawn.

# %% [markdown]
# # Indexing Data

# %% [raw]
# Data in a pandas data frame can be indexed position wise as well as logically by subjecting it to a logical condition.

# %% [raw]
# Data can be indexed position wise from a data frame the same way it is accessed in a 2D array. The first index refers to the feature name while the second index refers the concerned row. It is also helpful to visualize a pandas data frame as a set of pandas series stacked vertically together.
#
# For example, the second cell in 'age' column can be accessed as:

# %%
df['age'][1]
# Out:
# 57

# %% [raw]
# All entries of a column can also be indexed the same way. For the sake of visibility, let's retrieve the first five entries in 'age' column of data frame:

# %%
df['age'].head()
# Out:
# 0    56
# 1    57
# 2    37
# 3    40
# 4    56
# Name: age, dtype: int64

# %% [raw]
# Logical Indexing of data can also be done - the example below gives a boolean result for all entries in the 'age' column, it gives True if they are greather than 40 and gives False if they are less than 40.

# %%
print(df['age']>40)
# Out:
# 0         True
# 1         True
# 2        False
# 3        False
# 4         True
#          ...
# 41183     True
# 41184     True
# 41185     True
# 41186     True
# 41187     True
# Name: age, Length: 41188, dtype: bool

# %% [raw]
# There is one more method of logical indexing.
#
# The above example returns only the concerned column name (with index) having True and False values, which is not very useful.
# The below example returns a dataframe which has all rows (with all their features) that satisfy the given condition. Such information is suitable for further analysis and exploration.

# %%
print(df[df['age']>40])
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 4       56     services  married          high.school       no      no  yes
# 5       45     services  married             basic.9y  unknown      no   no
# 6       59       admin.  married  professional.course       no      no   no
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %% [raw]
# The above method is very suitable for further data analysis. For example, we can find out the mean values of numerical features for attracted clients as:

# %%
df[df['y']=='yes'].mean()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6968\2492207237.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df[df['y']=='yes'].mean()
# age                 40.913147
# duration           553.191164
# campaign             2.051724
# pdays              792.035560
# previous             0.492672
# emp.var.rate        -1.233448
# cons.price.idx      93.354386
# cons.conf.idx      -39.789784
# euribor3m            2.123135
# nr.employed       5095.115991
# dtype: float64

# %% [raw]
# The results above clearly show that the average call duration to attract a client is around 553 seconds, i.e., 9 minutes and 13 seconds. Also, the average age of an attracted client is 40 (as previously found out) and it took around 2 calls to attract them (campaign=2.051724).

# %% [markdown]
# # Sorting Data

# %% [raw]
# Entries in a data frame can be sorted by a single or even a group of columns.
#
# The sort_values() method sorts entries in a data frame and takes two arguments : feature name and order (ascending=True/False).
#
# The example below sorts entries of the data frame in descending order of 'age'. We only extract the first five entries for the sake of cleanliness.

# %%
df.sort_values(by='age', ascending=False).head()
# Out:
#        age      job   marital education  default housing loan   contact month  \
# 38452   98  retired   married  basic.4y  unknown     yes   no  cellular   oct
# 38455   98  retired   married  basic.4y  unknown     yes   no  cellular   oct
# 27826   95  retired  divorced  basic.6y       no      no   no  cellular   mar
# 38921   94  retired   married  basic.9y       no      no   no  cellular   nov
# 39655   92  retired   married   unknown       no     yes   no  cellular   may
#
#       day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 38452         fri  ...         1      2         2      success         -3.4
# 38455         fri  ...         2    999         0  nonexistent         -3.4
# 27826         thu  ...         1    999         0  nonexistent         -1.8
# 38921         wed  ...         1    999         1      failure         -3.4
# 39655         thu  ...         1      6         2      success         -1.8
#
# ...

# %% [raw]
# As mentioned above, entries can also be sorted by a group of features. The features and order both are passed as a list to the sort_values() method.
#
# For example, the example below sorts data frame entries in order of increasing age and decreasing duration. Again, we only take the first five entries.

# %%
df.sort_values(by=['age','duration'], ascending=[True,False]).head()
# Out:
#        age      job marital education default  housing     loan   contact  \
# 38274   17  student  single   unknown      no       no      yes  cellular
# 37579   17  student  single  basic.9y      no  unknown  unknown  cellular
# 37140   17  student  single   unknown      no      yes       no  cellular
# 37539   17  student  single  basic.9y      no      yes       no  cellular
# 37558   17  student  single  basic.9y      no      yes       no  cellular
#
#       month day_of_week  ...  campaign  pdays  previous  poutcome  \
# 38274   oct         tue  ...         1      2         2   success
# 37579   aug         fri  ...         2    999         1   failure
# 37140   aug         wed  ...         3      4         2   success
# 37539   aug         fri  ...         2    999         2   failure
# 37558   aug         fri  ...         3      4         2   success
#
#       emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed    y
# ...

# %%
df['age'].mean()
# Out:
# 40.02406040594348

# %% [markdown]
# # Cross Tabulation

# %% [raw]
# Cross Tabulation helps explore the data in data frame across any two features of choice. It is helpful in knowing how data is distributed between two features of the data frame.
#
# pandas provides the crosstab() method to construct a cross tabulation - it takes the names of desired features to be included in the cross tabulation as arguments.
#
# For example, below is a cross tabulation between clients who have purchased a term insurance and their marital status:

# %%
pd.crosstab(df['y'],df['marital'])
# Out:
# marital  divorced  married  single  unknown
# y
# no           4136    22396    9948       68
# yes           476     2532    1620       12

# %% [raw]
# The above cross tabulation indicates that clients who are maritally single are 4% more likely to purchase the insurance than the divorced and married clients.

# %% [markdown]
# # Visualization in pandas

# %% [raw]
# While the major visualization library in Python is 'Matplotlib', pandas too has some visualization methods in it.

# %% [raw]
# The scatter_matrix function constructs 'pair plots' for all features given as arguments to it. If no feature names are given as arguments, the scatter_matrix function constructs 'pair plots' for all numeric features.
#
# For example, the example below constructs pair plots for features 'age','duration' and 'campaign'.

# %%
pd.plotting.scatter_matrix(df[['age','duration','campaign']], figsize=(15,15))
# Out:
# array([[<AxesSubplot: xlabel='age', ylabel='age'>,
#         <AxesSubplot: xlabel='duration', ylabel='age'>,
#         <AxesSubplot: xlabel='campaign', ylabel='age'>],
#        [<AxesSubplot: xlabel='age', ylabel='duration'>,
#         <AxesSubplot: xlabel='duration', ylabel='duration'>,
#         <AxesSubplot: xlabel='campaign', ylabel='duration'>],
#        [<AxesSubplot: xlabel='age', ylabel='campaign'>,
#         <AxesSubplot: xlabel='duration', ylabel='campaign'>,
#         <AxesSubplot: xlabel='campaign', ylabel='campaign'>]],
#       dtype=object)

# %% [raw]
# Across the diagonal, we have the distribution of each feature. Other pair plots convey significant information of their own. For example, the pair plot between 'age' and 'duration' shows that the duration rarely exceeds 2000 seconds no matter the increase in age and most frequent duration is around 1000 seconds for all age groups.
# Several other inferences can be drawn by looking at other pair plots.

# %% [raw]
# A Hisogram is perhaps more suitable to gauge the distribution of a feature. It can be constructed using the hist() method provided by pandas.
# The example below constructs a histogram for 'age' feature of data frame.

# %%
df['age'].hist()
# Out:
# <AxesSubplot: >

# %% [raw]
# The above histogram shows that most of our potential customers are between 25 and 55 years of age, with the maximum being roughly between 35 and 42.

# %% [raw]
# The hist() function can also be used to construct histograms for all numeric features together, as shown below.

# %%
df.hist(figsize=(15,10))
# Out:
# array([[<AxesSubplot: title={'center': 'age'}>,
#         <AxesSubplot: title={'center': 'duration'}>,
#         <AxesSubplot: title={'center': 'campaign'}>],
#        [<AxesSubplot: title={'center': 'pdays'}>,
#         <AxesSubplot: title={'center': 'previous'}>,
#         <AxesSubplot: title={'center': 'emp.var.rate'}>],
#        [<AxesSubplot: title={'center': 'cons.price.idx'}>,
#         <AxesSubplot: title={'center': 'cons.conf.idx'}>,
#         <AxesSubplot: title={'center': 'euribor3m'}>],
#        [<AxesSubplot: title={'center': 'nr.employed'}>, <AxesSubplot: >,
#         <AxesSubplot: >]], dtype=object)
